# %%
import pandas as pd

# %%
nivel_entidad = pd.read_csv("nivel_entidad.csv")
orden_entidad = pd.read_csv("orden_entidad.csv")
municipio_entrega = pd.read_csv("municipio_entrega.csv",encoding="latin-1",sep=";")
municipio_obtencion = pd.read_csv("municipio_obtencion.csv",encoding="latin-1",sep=";")
municipios_ejecucion = pd.read_csv("municipios_ejecucion.csv",encoding="latin-1",sep=";")

# %%
nivel_entidad.set_index("nivel_entidad_original").to_dict()
# Out:
# {'nivel_entidad': {'NACIONAL': 0, 'No Definida': 1, 'TERRITORIAL': 2}}

# %%
orden_entidad.set_index("orden_entidad_original").to_dict()
# Out:
# {'orden_entidad': {'DISTRITO CAPITAL': 0,
#   'NACIONAL CENTRALIZADO': 1,
#   'NACIONAL DESCENTRALIZADO': 2,
#   'No Definido': 3,
#   'TERRITORIAL DEPARTAMENTAL CENTRALIZADO': 4,
#   'TERRITORIAL DEPARTAMENTAL DESCENTRALIZADO': 5,
#   'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 1': 6,
#   'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 2': 7,
#   'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 3': 8,
#   'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 4': 9,
#   'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 5': 10,
#   'TERRITORIAL DISTRITAL MUNICIPAL NIVEL 6': 11}}

# %%
municipios_ejecucion.set_index("municipios_ejecucion_original").to_dict()['municipios_ejecucion']
# Out:
# {'Abejorral': 0,
#  'Abrego': 1,
#  'Abriaquí': 2,
#  'Acacías': 3,
#  'Acandí': 4,
#  'Acevedo': 5,
#  'Achí': 6,
#  'Agrado': 7,
#  'Agua de Dios': 9,
#  'Aguachica': 10,
#  'Aguada': 11,
#  'Aguadas': 8,
#  'Aguazul': 12,
#  'Agustín Codazzi': 13,
#  'Aipe': 14,
#  'Albán': 16,
#  'Albania': 15,
#  'Alcalá': 17,
#  'Aldana': 18,
#  'Alejandría': 19,
#  'Algarrobo': 20,
#  'Algeciras': 21,
#  'Almaguer': 22,
#  'Almeida': 23,
#  'Alpujarra': 24,
#  'Altamira': 25,
#  'Alto Baudo': 26,
#  'Altos del Rosario': 27,
#  'Alvarado': 28,
#  'Amagá': 29,
#  'Amalfi': 30,
#  'Ambalema': 31,
#  'Anapoima': 32,
#  'Ancuyá': 33,
#  'Andalucía': 34,
#  'Andes': 35,
#  'Angelópolis': 36,
#  'Angostura': 37,
#  'Anolaima': 38,
#  'Anorí': 39,
#  'Anserma': 40,
#  'Ansermanuevo': 41,
#  'Anza': 42,
#  'Anzoátegui': 43,
#  'Apartadó': 46,
#  'Apía': 44,
#  'Apulo': 45,
#  'Aquitania': 47,
#  'Aracataca': 48,
#  'Aranzazu': 49,
#  'Aratoca': 50,
#  'Arauca': 51,
#  'Arauquita': 52,
#  'Arbeláez': 53,
#  'Arboleda': 54,
#  'Arboledas': 55,
#  'Arboletes': 56,
#  'Arcabuco': 57,
#  'Arenal': 58,
#  'Argelia': 59,
#  'Ariguaní/El Dificil': 60,
#  'Arjona': 61,
#  'Armenia': 62,
#  'Armero': 63,
#  'Arroyohondo': 64,
#  'Astrea': 65,
#  'Ataco': 66,
#  'Atrato': 1048,
#  'Ayapel': 67,
#  'Bagadó': 68,
#  'Bahía Solano': 69,
#  'Bajo Baudó/Pizarro': 70,
#  'Balboa': 71,
#  'Baranoa': 72,
#  'Baraya': 73,
#  'Barbacoas': 74,
#  'Barbosa': 75,
#  'Barichara': 76,
#  'Barranca de Upía': 77,
#  'Barrancabermeja': 79,
#  'Barrancas': 78,
#  'Barranco de Loba': 80,
#  'Barranco Minas': 82,
#  'Barranquilla': 81,
#  'Becerril': 83,
#  'Belalcázar': 84,
#  'Belén': 85,
#  'Belén de Bajirá': 89,
#  'Belén de Los Andaquies': 90,
#  'Belén de Umbría': 91,
#  'Bello': 92,
#  'Belmira': 86,
#  'Beltrán': 87,
#  'Berbeo': 88,
#  'Berruecos': 93,
#  'Betania': 94,
#  'Betéitiva': 97,
#  'Betulia': 95,
#  'Bituima': 96,
#  'Boavita': 98,
#  'Bocas De Satinga': 99,
#  'Bochalema': 100,
#  'Bogotá D.C.': 101,
#  'Bojacá': 102,
#  'Bojaya': 103,
#  'Bolívar': 104,
#  'Bolivia': 106,
#  'Bosconia': 105,
#  'Boyacá': 107,
#  'Briceño': 108,
#  'Bucaramanga': 109,
#  'Bucarasica': 110,
#  'Buenaventura': 111,
#  'Buenavista': 112,
#  'Buenos Aires': 113,
#  'Buesaco': 114,
#  'Bugalagrande': 115,
#  'Buriticá': 116,
#  'Busbanzá': 117,
#  'Cabrera': 118,
#  'Cabuyaro': 252,
#  'Cacahual': 253,
#  'Cáceres': 163,
#  'Cachipay': 119,
#  'Cachirá': 120,
#  'Cácota': 121,
#  'Caicedo': 249,
#  'Caicedonia': 122,
#  'Caimito': 123,
#  'Cajamarca': 250,
#  'Cajibío': 124,
#  'Cajicá': 125,
#  'Calamar': 126,
#  'Calarca': 127,
#  'Caldas': 128,
#  'Caldono': 129,
#  'Cali': 130,
#  'California': 131,
#  'Calima': 132,
#  'Caloto': 133,
#  'Campamento': 134,
#  'Campo de la Cruz': 135,
#  'Campoalegre': 136,
#  'Campohermoso': 137,
#  'Canalete': 138,
#  'Candelaria': 140,
#  'Cantagallo': 139,
#  'Cañasgordas': 141,
#  'Caparrapí': 142,
#  'Capitanejo': 143,
#  'Caqueza': 144,
#  'Caracolí': 145,
#  'Caramanta': 146,
#  'Carcasí': 147,
#  'Carepa': 148,
#  'Carmen de Apicalá': 149,
#  'Carmen de Carupa': 150,
#  'Carmen del Darien': 151,
#  'Carolina del Príncipe': 152,
#  'Cartagena': 153,
#  'Cartagena del Chairá': 154,
#  'Cartago': 155,
#  'Caruru': 156,
#  'Casabianca': 157,
#  'Castilla La Nueva': 158,
#  'Caucasia': 251,
#  'Cepitá': 159,
#  'Cereté': 160,
#  'Cerinza': 161,
#  'Cerrito': 162,
#  'Cerro San Antonio': 164,
#  'Cértegui': 165,
#  'Chachagüí': 166,
#  'Chaguaní': 167,
#  'Chalán': 168,
#  'Chameza': 197,
#  'Chaparral': 169,
#  'Charalá': 170,
#  'Charta': 171,
#  'Chía': 172,
#  'Chibolo': 173,
#  'Chigorodó': 198,
#  'Chima': 174,
#  'Chimá': 175,
#  'Chimichagua': 176,
#  'Chinácota': 177,
#  'Chinavita': 178,
#  'Chinchiná': 180,
#  'Chinú': 179,
#  'Chipaque': 183,
#  'Chipatá': 184,
#  'Chiquinquirá': 181,
#  'Chíquiza (San Pedro de Iguaque)': 182,
#  'Chiriguaná': 185,
#  'Chiscas': 186,
#  'Chita': 187,
#  'Chitagá': 188,
#  'Chitaraque': 189,
#  'Chivatá': 190,
#  'Chivor': 191,
#  'Choachí': 192,
#  'Chocontá': 193,
#  'Cicuco': 194,
#  'Ciénaga': 195,
#  'Ciénaga de Oro': 196,
#  'Ciénega': 204,
#  'Cimitarra': 205,
#  'Circasia': 206,
#  'Cisneros': 199,
#  'Ciudad Bolívar': 200,
#  'Clemencia': 201,
#  'Cocorná': 202,
#  'Coello': 203,
#  'Cogua': 207,
#  'Colombia': 208,
#  'Colón': 209,
#  'Coloso': 210,
#  'Cómbita': 213,
#  'Concepción': 211,
#  'Concordia': 212,
#  'Condoto': 214,
#  'Confines': 215,
#  'Consaca': 216,
#  'Contadero': 217,
#  'Contratación': 218,
#  'Convención': 219,
#  'Copacabana': 220,
#  'Coper': 221,
#  'Córdoba': 222,
#  'Corinto': 223,
#  'Coromoro': 224,
#  'Corozal': 225,
#  'Corrales': 226,
#  'Cota': 227,
#  'Cotorra': 228,
#  'Covarachía': 229,
#  'Coveñas': 230,
#  'Coyaima': 231,
#  'Cravo Norte': 232,
#  'Cuaspud/Carlosama': 233,
#  'Cubará': 234,
#  'Cubarral': 248,
#  'Cucaita': 236,
#  'Cucunubá': 235,
#  'Cucutilla': 237,
#  'Cuítiva': 238,
#  'Cumaral': 239,
#  'Cumaribo': 240,
#  'Cumbal': 241,
#  'Cumbitara': 242,
#  'Cunday': 243,
#  'Curillo': 244,
#  'Curití': 245,
#  'Curumaní': 246,
#  'Dabeiba': 247,
#  'Dagua': 254,
#  'Dibulla': 255,
#  'Distracción': 256,
#  'Dolores': 257,
#  'Don Matías': 258,
#  'Dosquebradas': 259,
#  'Duitama': 260,
#  'Durania': 261,
#  'Ebéjico': 262,
#  'El Águila': 263,
#  'El Bagre': 311,
#  'El Banco': 310,
#  'El Cairo': 264,
#  'El Calvario': 265,
#  'El Cantón del San Pablo': 266,
#  'El Carmen': 267,
#  'El Carmen de Atrato': 268,
#  'El Carmen de Bolívar': 269,
#  'El Carmen de Chucurí': 270,
#  'El Carmen de Viboral': 271,
#  'El Castillo': 272,
#  'El Cerrito': 273,
#  'El Charco': 274,
#  'El Cocuy': 275,
#  'El Colegio': 276,
#  'El Copey': 277,
#  'El Difícil': 278,
#  'El Doncello': 279,
#  'El Dorado': 280,
#  'El Dovio': 281,
#  'El Encanto': 282,
#  'El Espinal': 283,
#  'El Espino': 284,
#  'El Guacamayo': 285,
#  'El Guamo': 286,
#  'El Líbano': 287,
#  'El Litoral del San Juan': 288,
#  'El Molino': 290,
#  'El Paso': 289,
#  'El Paujil': 291,
#  'El Peñol': 292,
#  'El Peñón': 293,
#  'El Piñon': 295,
#  'El Pital': 294,
#  'El Playón': 297,
#  'El Retén': 296,
#  'El Retiro': 298,
#  'El Retorno': 301,
#  'El Roble': 299,
#  'El Rosal': 300,
#  'El Rosario': 302,
#  'El Santuario': 303,
#  'El Tablón de Gómez': 304,
#  'El Tambo': 305,
#  'El Tarra': 306,
#  'El Zulia': 307,
#  'Elías': 308,
#  'Encino': 309,
#  'Enciso': 312,
#  'Entrerrios': 313,
#  'Envigado': 314,
#  'Facatativá': 315,
#  'Falan': 316,
#  'Filadelfia': 317,
#  'Filandia': 340,
#  'Firavitoba': 318,
#  'Flandes': 319,
#  'Florencia': 320,
#  'Floresta': 321,
#  'Florián': 322,
#  'Florida': 323,
#  'Floridablanca': 326,
#  'Fomeque': 324,
#  'Fonseca': 325,
#  'Fortul': 327,
#  'Fosca': 328,
#  'Francisco Pizarro': 329,
#  'Fredonia': 330,
#  'Fresno': 331,
#  'Frontino': 332,
#  'Fuente de Oro': 333,
#  'Fundación': 334,
#  'Funes': 335,
#  'Funza': 336,
#  'Fúquene': 337,
#  'Fusagasugá': 338,
#  'Gachalá': 339,
#  'Gachancipá': 393,
#  'Gachantivá': 394,
#  'Gachetá': 392,
#  'Galán': 341,
#  'Galapa': 342,
#  'Galeras': 343,
#  'Gama': 344,
#  'Gamarra': 347,
#  'Gambita': 345,
#  'Gameza': 346,
#  'Garagoa': 348,
#  'Garzón': 349,
#  'Génova': 350,
#  'Gigante': 351,
#  'Ginebra': 391,
#  'Giraldo': 352,
#  'Girardot': 353,
#  'Girardota': 354,
#  'Girón': 355,
#  'Gómez Plata': 359,
#  'González': 356,
#  'Gramalote': 357,
#  'Granada': 358,
#  'Guaca': 360,
#  'Guacamayas': 361,
#  'Guacarí': 362,
#  'Guachené': 363,
#  'Guachetá': 364,
#  'Guachucal': 365,
#  'Guadalajara de Buga': 366,
#  'Guadalupe': 367,
#  'Guaduas': 368,
#  'Guaitarilla': 369,
#  'Gualmatán': 370,
#  'Guamal': 371,
#  'Guapi': 372,
#  'Guapotá': 373,
#  'Guaranda': 374,
#  'Guarne': 375,
#  'Guasca': 376,
#  'Guatapé': 377,
#  'Guataquí': 378,
#  'Guatavita': 379,
#  'Guateque': 380,
#  'Guática': 381,
#  'Guavatá': 382,
#  'Guayabal': 383,
#  'Guayabal de Siquima': 390,
#  'Guayabetal': 384,
#  'Guayatá': 385,
#  'Güepsa': 386,
#  'Güicán': 387,
#  'Gutiérrez': 388,
#  'Hacarí': 389,
#  'Hatillo de Loba': 395,
#  'Hato': 396,
#  'Hato Corozal': 397,
#  'Hatonuevo': 398,
#  'Heliconia': 399,
#  'Herrán': 400,
#  'Herveo': 401,
#  'Hispania': 402,
#  'Hobo': 403,
#  'Honda': 404,
#  'Ibagué': 405,
#  'Icononzo': 406,
#  'Iles': 407,
#  'Imués': 408,
#  'Inírida': 409,
#  'Inzá': 411,
#  'Ipiales': 410,
#  'Iquira': 412,
#  'Isnos': 413,
#  'Istmina': 414,
#  'Itagüí': 415,
#  'Ituango': 416,
#  'Iza': 417,
#  'Jambaló': 418,
#  'Jamundi': 419,
#  'Jardín': 420,
#  'Jenesano': 421,
#  'Jericó': 422,
#  'Jerusalén': 423,
#  'Jesús María': 424,
#  'Jordán': 425,
#  'Juan de Acosta': 426,
#  'Junín': 427,
#  'Juradó': 428,
#  'La Apartada': 429,
#  'La Argentina': 490,
#  'La Belleza': 430,
#  'La Calera': 431,
#  'La Capilla': 470,
#  'La Ceja': 432,
#  'La Celia': 471,
#  'La Chorrera': 433,
#  'La Cruz': 434,
#  'La Cumbre': 435,
#  'La Dorada': 436,
#  'La Esperanza': 437,
#  'La Estrella': 438,
#  'La Florida': 439,
#  'La Gloria': 440,
#  'La Guadalupe': 441,
#  'La Jagua de Ibirico': 442,
#  'La Jagua Del Pilar': 443,
#  'La Llanada': 444,
#  'La Macarena': 445,
#  'La Merced': 447,
#  'La Mesa': 446,
#  'La Montañita': 448,
#  'La Palma': 449,
#  'La Paz': 450,
#  'La Pedrera': 451,
#  'La Peña': 452,
#  'La Pintada': 472,
#  'La Plata': 453,
#  'La Playa de Belen': 454,
#  'La Primavera': 456,
#  'La Salina': 455,
#  'La Sierra': 457,
#  'La Tebaida': 458,
#  'La Tola': 459,
#  'La Unión': 460,
#  'La Uvita': 489,
#  'La Vega': 461,
#  'La Victoria': 462,
#  'La Virginia': 463,
#  'Labateca': 464,
#  'Labranzagrande': 465,
#  'Landázuri': 466,
#  'Lebríja': 467,
#  'Leiva': 468,
#  'Lejanías': 469,
#  'Lenguazaque': 473,
#  'Lérida': 474,
#  'Leticia': 475,
#  'Liborina': 476,
#  'Linares': 477,
#  'Lloró': 478,
#  'López de Micay': 479,
#  'Lorica': 480,
#  'Los Andes': 481,
#  'Los Córdobas': 482,
#  'Los Palmitos': 483,
#  'Los Patios': 484,
#  'Los Santos': 485,
#  'Lourdes': 486,
#  'Luruaco': 487,
#  'Macanal': 488,
#  'Macaravita': 491,
#  'Maceo': 492,
#  'Macheta': 493,
#  'Madrid': 494,
#  'Magangué': 495,
#  'Magüi': 497,
#  'Mahates': 496,
#  'Maicao': 498,
#  'Majagual': 499,
#  'Málaga': 500,
#  'Malambo': 562,
#  'Mallama': 501,
#  'Manatí': 502,
#  'Manaure': 509,
#  'Manaure Balcon del Cesar': 503,
#  'Maní': 504,
#  'Manizales': 505,
#  'Manta': 506,
#  'Manzanares': 507,
#  'Mapiripán': 508,
#  'Mapiripana': 511,
#  'Margarita': 510,
#  'María La Baja': 519,
#  'Marinilla': 512,
#  'Maripí': 513,
#  'Marmato': 514,
#  'Marquetalia': 515,
#  'Marsella': 516,
#  'Marulanda': 517,
#  'Matanza': 518,
#  'Medellín': 520,
#  'Medellín de Ariari': 521,
#  'Medina': 522,
#  'Medio Atrato': 523,
#  'Medio Baudó': 524,
#  'Medio San Juan/Andagoya': 525,
#  'Melgar': 526,
#  'Mercaderes': 527,
#  'Mesetas': 528,
#  'Milán': 529,
#  'Miraflores': 530,
#  'Miranda': 531,
#  'Miriti': 532,
#  'Mistrató': 533,
#  'Mitú': 534,
#  'Mogotes': 535,
#  'Molagavita': 556,
#  'Momil': 536,
#  'Mompós': 537,
#  'Mongua': 538,
#  'Monguí': 539,
#  'Moniquirá': 540,
#  'Montebello': 541,
#  'Montebonito': 542,
#  'Montecristo': 543,
#  'Montelíbano': 544,
#  'Montenegro': 545,
#  'Montería': 546,
#  'Monterrey': 547,
#  'Moñitos': 549,
#  'Morales': 548,
#  'Morelia': 550,
#  'Morichal': 551,
#  'Morroa': 552,
#  'Mosquera': 553,
#  'Motavita': 554,
#  'Murillo': 555,
#  'Murindó': 557,
#  'Mutatá': 558,
#  'Mutiscua': 559,
#  'Muzo': 560,
#  'Nariño': 561,
#  'Nátaga': 581,
#  'Natagaima': 563,
#  'Nechí': 580,
#  'Necoclí': 564,
#  'Neira': 565,
#  'Neiva': 566,
#  'Nemocón': 567,
#  'Nilo': 568,
#  'Nimaima': 569,
#  'Nobsa': 570,
#  'Nocaima': 571,
#  'Norcasia': 572,
#  'Norosí': 573,
#  'Nóvita': 574,
#  'Nueva Granada': 575,
#  'Nuevo Colón': 576,
#  'Nunchía': 577,
#  'Nuquí': 578,
#  'Obando': 579,
#  'Ocamonte': 582,
#  'Ocaña': 584,
#  'Oiba': 583,
#  'Oicatá': 585,
#  'Olaya': 586,
#  'Olaya Herrera': 587,
#  'Onzaga': 588,
#  'Oporapa': 589,
#  'Orito': 590,
#  'Orocué': 591,
#  'Ortega': 592,
#  'Ospina': 593,
#  'Otanche': 594,
#  'Ovejas': 595,
#  'Pachavita': 596,
#  'Pacho': 597,
#  'Pacoa': 598,
#  'Pácora': 599,
#  'Padilla': 696,
#  'Páez': 600,
#  'Paez/Belalcazar': 697,
#  'Paicol': 601,
#  'Pailitas': 602,
#  'Paime': 603,
#  'Paipa': 604,
#  'Pajarito': 605,
#  'Palermo': 606,
#  'Palestina': 607,
#  'Palmar': 608,
#  'Palmar de Varela': 609,
#  'Palmas del Socorro': 610,
#  'Palmira': 611,
#  'Palmito': 612,
#  'Palocabildo': 613,
#  'Pamplona': 614,
#  'Pamplonita': 615,
#  'Pandi': 616,
#  'Panqueba': 617,
#  'Páramo': 618,
#  'Paratebueno': 698,
#  'Pasca': 619,
#  'Pasto': 620,
#  'Patía': 621,
#  'Pauna': 622,
#  'Paya': 623,
#  'Paz de Ariporo': 624,
#  'Paz de Río': 625,
#  'Pedraza': 626,
#  'Pelaya': 627,
#  'Pensilvania': 628,
#  'Peque': 629,
#  'Pereira': 630,
#  'Pesca': 631,
#  'Piamonte': 632,
#  'Piedecuesta': 633,
#  'Piedras': 634,
#  'Piendamó': 635,
#  'Pijao': 636,
#  'Pijiño del Carmen': 637,
#  'Pinchote': 638,
#  'Pinillos': 639,
#  'Piojó': 640,
#  'Pisba': 641,
#  'Pitalito': 642,
#  'Pivijay': 643,
#  'Planadas': 644,
#  'Planeta Rica': 645,
#  'Plato': 646,
#  'Policarpa': 647,
#  'Polonuevo': 648,
#  'Ponedera': 649,
#  'Popayán': 650,
#  'Pore': 651,
#  'Potosí': 652,
#  'Pradera': 653,
#  'Prado': 654,
#  'Providencia': 655,
#  'Pueblo Bello': 656,
#  'Pueblo Nuevo': 657,
#  'Pueblo Rico': 658,
#  'Pueblorrico': 659,
#  'Puebloviejo': 660,
#  'Puente Nacional': 661,
#  'Puerres': 662,
#  'Puerto Alegría': 663,
#  'Puerto Arica': 664,
#  'Puerto Asís': 665,
#  'Puerto Berrío': 666,
#  'Puerto Bolívar': 667,
#  'Puerto Boyacá': 668,
#  'Puerto Caicedo': 669,
#  'Puerto Carreño': 670,
#  'Puerto Colombia': 671,
#  'Puerto Concordia': 672,
#  'Puerto Escondido': 673,
#  'Puerto Gaitán': 674,
#  'Puerto Guzmán': 675,
#  'Puerto Leguízamo': 676,
#  'Puerto Libertador': 680,
#  'Puerto Lleras': 677,
#  'Puerto López': 678,
#  'Puerto Nare': 679,
#  'Puerto Nariño': 681,
#  'Puerto Parra': 682,
#  'Puerto Rico': 683,
#  'Puerto Rondón': 684,
#  'Puerto Salgar': 685,
#  'Puerto Santander': 686,
#  'Puerto Tejada': 687,
#  'Puerto Triunfo': 688,
#  'Puerto Wilches': 689,
#  'Pulí': 690,
#  'Pupiales': 691,
#  'Puracé': 692,
#  'Purificación': 693,
#  'Purísima': 695,
#  'Quebradanegra': 694,
#  'Quetame': 705,
#  'Quibdó': 699,
#  'Quimbaya': 700,
#  'Quinchía': 701,
#  'Quípama': 702,
#  'Quipile': 703,
#  'Ragonvalia': 704,
#  'Ramiriquí': 706,
#  'Ráquira': 707,
#  'Recetor': 732,
#  'Regidor': 729,
#  'Remedios': 730,
#  'Remolino': 731,
#  'Repelón': 728,
#  'Restrepo': 708,
#  'Ricaurte': 709,
#  'Río de Oro': 710,
#  'Río Iro': 711,
#  'Río Quito': 712,
#  'Río Viejo': 713,
#  'Rioblanco': 714,
#  'Riofrío': 715,
#  'Riohacha': 716,
#  'Rionegro': 717,
#  'Riosucio': 718,
#  'Risaralda': 719,
#  'Rivera': 720,
#  'Roberto Payán/San José': 721,
#  'Roldanillo': 722,
#  'Roncesvalles': 723,
#  'Rondón': 724,
#  'Rosas': 725,
#  'Rovira': 726,
#  'Sabana de Torres': 727,
#  'Sabanagrande': 733,
#  'Sabanalarga': 734,
#  'Sabanas de San Angel': 735,
#  'Sabaneta': 736,
#  'Saboyá': 737,
#  'Sácama': 738,
#  'Sáchica': 908,
#  'Sahagún': 909,
#  'Saladoblanco': 739,
#  'Salamina': 740,
#  'Salazar de las Palmas': 741,
#  'Saldaña': 742,
#  'Salento': 743,
#  'Salgar': 744,
#  'Samacá': 745,
#  'Samaná': 746,
#  'Samaniego': 748,
#  'Sampués': 747,
#  'San Agustín': 749,
#  'San Alberto': 750,
#  'San Andrés': 751,
#  'San Andrés de Cuerquia': 753,
#  'San Andres de Tumaco': 755,
#  'San Andrés Sotavento': 754,
#  'San Antero': 752,
#  'San Antonio': 756,
#  'San Antonio del Tequendama': 757,
#  'San Benito': 758,
#  'San Benito Abad': 759,
#  'San Bernardo': 760,
#  'San Bernardo del Viento': 761,
#  'San Calixto': 762,
#  'San Carlos': 763,
#  'San Carlos de Guaroa': 764,
#  'San Cayetano': 765,
#  'San Cristóbal': 766,
#  'San Diego': 767,
#  'San Eduardo': 768,
#  'San Estanislao de Kostka': 825,
#  'San Felipe': 769,
#  'San Felix': 770,
#  'San Fernando': 771,
#  'San Francisco': 772,
#  'San Gil': 773,
#  'San Jacinto': 774,
#  'San Jacinto del Cauca': 775,
#  'San Jerónimo': 776,
#  'San Joaquín': 777,
#  'San José': 778,
#  'San José de Cúcuta': 779,
#  'San José de la Montaña': 780,
#  'San José de Miranda': 781,
#  'San José de Pare': 785,
#  'San José de Uré': 786,
#  'San José del Fragua': 787,
#  'San José del Guaviare': 788,
#  'San José del Palmar': 782,
#  'San Juan de Arama': 783,
#  'San Juan de Betulia': 784,
#  'San Juan de Río Seco': 790,
#  'San Juan de Urabá': 791,
#  'San Juan del Cesar': 794,
#  'San Juan Nepomuceno': 792,
#  'San Juanito': 793,
#  'San Lorenzo': 795,
#  'San Luis': 789,
#  'San Luis de Gaceno': 796,
#  'San Luis de Palenque': 797,
#  'San Marcos': 798,
#  'San Martín': 799,
#  'San Martín de Loba': 800,
#  'San Mateo': 801,
#  'San Miguel': 802,
#  'San Miguel (La Dorada)': 803,
#  'San Miguel de Mocoa': 804,
#  'San Miguel de Sema': 806,
#  'San Onofre': 807,
#  'San Pablo': 805,
#  'San Pablo de Borbur': 808,
#  'San Pedro': 809,
#  'San Pedro de Cartago': 810,
#  'San Pedro de los Milagros': 811,
#  'San Pedro de Uraba': 812,
#  'San Pelayo': 814,
#  'San Rafael': 813,
#  'San Roque': 815,
#  'San Sebastián': 816,
#  'San Sebastián de Buenavista': 817,
#  'San Sebastian de Mariquita': 819,
#  'San Vicente': 820,
#  'San Vicente de Chucurí': 818,
#  'San Vicente del Caguán': 826,
#  'San Zenón': 827,
#  'Sandona': 828,
#  'Santa Ana': 829,
#  'Santa Bárbara': 843,
#  'Santa Bárbara de Pinto': 844,
#  'Santa Catalina': 830,
#  'Santa Helena del Opón': 831,
#  'Santa Isabel': 832,
#  'Santa Lucía': 834,
#  'Santa María': 833,
#  'Santa Marta': 845,
#  'Santa Rosa': 846,
#  'Santa Rosa de Cabal': 835,
#  'Santa Rosa de Lima': 836,
#  'Santa Rosa de Osos': 837,
#  'Santa Rosa de Viterbo': 840,
#  'Santa Rosa del Sur': 838,
#  'Santa Rosalía': 839,
#  'Santa Sofía': 841,
#  'Santacruz': 842,
#  'Santafé de Antioquia': 847,
#  'Santana': 848,
#  'Santander de Quilichao': 851,
#  'Santiago': 849,
#  'Santiago de Tolú': 850,
#  'Santo Domingo': 852,
#  'Santo Tomás': 821,
#  'Santodomigo de Silos': 822,
#  'Santuario': 823,
#  'Sapuyes': 824,
#  'Saravena': 853,
#  'Sardinata': 854,
#  'Sasaima': 855,
#  'Sativanorte': 856,
#  'Sativasur': 857,
#  'Segovia': 858,
#  'Sesquilé': 859,
#  'Sevilla': 860,
#  'Siachoque': 861,
#  'Sibaté': 862,
#  'Sibundoy': 863,
#  'Silvania': 864,
#  'Silvia': 865,
#  'Simacota': 866,
#  'Simijaca': 867,
#  'Simití': 868,
#  'Sincé': 869,
#  'Sincelejo': 871,
#  'Sipí': 870,
#  'Sitionuevo': 872,
#  'Soacha': 873,
#  'Soatá': 874,
#  'Socha': 875,
#  'Socorro': 876,
#  'Socotá': 877,
#  'Sogamoso': 878,
#  'Solano': 879,
#  'Soledad': 880,
#  'Solita': 881,
#  'Somondoco': 882,
#  'Sonsón': 883,
#  'Sopetrán': 884,
#  'Soplaviento': 887,
#  'Sopó': 885,
#  'Sora': 886,
#  'Soracá': 888,
#  'Sotaquirá': 889,
#  'Sotara': 890,
#  'Sotomayor': 891,
#  'Suaita': 892,
#  'Suan': 893,
#  'Suárez': 894,
#  'Suaza': 907,
#  'Subachoque': 895,
#  'Sucre': 896,
#  'Suesca': 897,
#  'Supatá': 898,
#  'Supía': 900,
#  'Suratá': 899,
#  'Susa': 901,
#  'Susacón': 902,
#  'Sutamarchán': 903,
#  'Sutatausa': 904,
#  'Sutatenza': 905,
#  'Tabio': 906,
#  'Tadó': 975,
#  'Talaigua Nuevo': 910,
#  'Tamalameque': 911,
#  'Támara': 912,
#  'Tame': 913,
#  'Támesis': 973,
#  'Taminango': 914,
#  'Tangua': 974,
#  'Taraira': 915,
#  'Tarapacá': 916,
#  'Tarazá': 976,
#  'Tarqui': 917,
#  'Tarso': 918,
#  'Tasco': 919,
#  'Tauramena': 920,
#  'Tausa': 921,
#  'Tello': 922,
#  'Tena': 923,
#  'Tenerife': 924,
#  'Tenjo': 925,
#  'Tenza': 926,
#  'Teorama': 927,
#  'Teruel': 928,
#  'Tesalia': 929,
#  'Tibacuy': 930,
#  'Tibaná': 931,
#  'Tibasosa': 932,
#  'Tibirita': 933,
#  'Tibú': 934,
#  'Tierralta': 937,
#  'Timaná': 935,
#  'Timbío': 936,
#  'Timbiquí': 938,
#  'Tinjacá': 939,
#  'Tipacoque': 941,
#  'Tiquisio': 940,
#  'Titiribí': 942,
#  'Toca': 943,
#  'Tocaima': 944,
#  'Tocancipá': 945,
#  'Todo el pais': 946,
#  'Togüí': 947,
#  'Toledo': 948,
#  'Tolemaida': 949,
#  'Toluviejo': 950,
#  'Tona': 951,
#  'Tópaga': 952,
#  'Topaipí': 953,
#  'Toribio': 954,
#  'Toro': 955,
#  'Tota': 956,
#  'Totoró': 957,
#  'Trinidad': 958,
#  'Trujillo': 959,
#  'Tubará': 960,
#  'Tuchín': 961,
#  'Tuluá': 962,
#  'Tunja': 963,
#  'Tununguá': 964,
#  'Túquerres': 965,
#  'Turbaco': 966,
#  'Turbaná': 967,
#  'Turbo': 968,
#  'Turmequé': 969,
#  'Tuta': 970,
#  'Tutazá': 971,
#  'Ubalá': 972,
#  'Ubaque': 977,
#  'Ulloa': 978,
#  'Umbita': 979,
#  'Une': 980,
#  'Unguía': 981,
#  'Unión Panamericana': 982,
#  'Uramita': 983,
#  'Uribe': 984,
#  'Uribia': 985,
#  'Urrao': 986,
#  'Urumita': 987,
#  'Usiacurí': 988,
#  'Útica': 989,
#  'Valdivia': 990,
#  'Valencia': 991,
#  'Valle de San José': 1027,
#  'Valle de San Juan': 994,
#  'Valle del Guamuez/La Hormiga': 992,
#  'Valledupar': 993,
#  'Valparaíso': 995,
#  'Vegachí': 996,
#  'Vélez': 997,
#  ...}

# %%
municipios_ejecucion
# Out:
#       municipios_ejecucion municipios_ejecucion_original
# 0                        0                     Abejorral
# 1                        1                        Abrego
# 2                        2                      Abriaquí
# 3                        3                       Acacías
# 4                        4                        Acandí
# 5                        5                       Acevedo
# 6                        6                          Achí
# 7                        7                        Agrado
# 8                        9                  Agua de Dios
# 9                       10                     Aguachica
# 10                      11                        Aguada
# 11                       8                       Aguadas
# 12                      12                       Aguazul
# 13                      13               Agustín Codazzi
# 14                      14                          Aipe
# 15                      16                         Albán
# 16                      15                       Albania
# 17                      17                        Alcalá
# 18                      18                        Aldana
# 19                      19                    Alejandría
# 20                      20                     Algarrobo
# 21                      21                     Algeciras
# 22                      22                      Almaguer
# 23                      23                       Almeida
# 24                      24                     Alpujarra
# 25                      25                      Altamira
# 26                      26                    Alto Baudo
# 27                      27             Altos del Rosario
# 28                      28                      Alvarado
# 29                      29                         Amagá
# ...                    ...                           ...
# 1019                  1018                    Villanueva
# 1020                  1010                   Villapinzón
# 1021                  1019                    Villarrica
# 1022                  1020                 Villavicencio
# 1023                  1021                    Villavieja
# 1024                  1022                       Villeta
# 1025                  1023                         Viotá
# 1026                  1024                     Viracachá
# 1027                  1025                  Vistahermosa
# 1028                  1026                       Viterbo
# 1029                  1028                        Yacopí
# 1030                  1029                    Yacuanquer
# 1031                  1030                       Yaguará
# 1032                  1031                          Yalí
# 1033                  1032                       Yarumal
# 1034                  1033                      Yavaraté
# 1035                  1034                       Yolombo
# 1036                  1035                         Yondó
# 1037                  1036                         Yopal
# 1038                  1037                        Yotoco
# 1039                  1038                         Yumbo
# 1040                  1039                      Zambrano
# 1041                  1040                      Zapatoca
# 1042                  1041                       Zapayán
# 1043                  1042                      Zaragoza
# 1044                  1043                        Zarzal
# 1045                  1044                     Zetaquira
# 1046                  1045                       Zipacón
# 1047                  1046                  ZipaquirÃÂ¡
# 1048                  1047                 Zona Bananera
#
# [1049 rows x 2 columns]

# %%
latitud=pd.read_csv("data_latitud.csv")

# %%
latitud.set_index("nombre").to_dict()["longitud"]
# Out:
# {'Amazonas': -69.94055999999999,
#  'Antioquia': -75.563591,
#  'Arauca': -70.759079,
#  'Atlántico': -74.7813187,
#  'Bogotá D.C.': -74.081749,
#  'Bolívar': -75.51444240000001,
#  'Boyacá': -73.36778259999998,
#  'Caldas': -75.5173798,
#  'Caquetá': -75.60623170000001,
#  'Casanare': -72.3958588,
#  'Cauca': -76.61315920000001,
#  'Cesar': -73.2532196,
#  'Chocó': -76.6583481,
#  'Colombia': nan,
#  'Córdoba': -75.8814316,
#  'Cundinamarca': -74.0048065,
#  'Guainía': -67.917,
#  'Guaviare': -72.64591,
#  'Huila': -75.28189090000001,
#  'La Guajira': -72.907289,
#  'Magdalena': -74.1990433,
#  'Meta': -73.62664029999999,
#  'Nariño': -77.2811127,
#  'Norte De Santander': -72.50782009999999,
#  'Otros Paises': nan,
#  'Putumayo': -76.64661,
#  'Quindío': -75.68110659999999,
#  'Risaralda': -75.69611359999999,
#  'San Andrés Providencia y Santa Catalina': -81.70056149999999,
#  'Santander': -73.1197968,
#  'Sucre': -75.3977814,
#  'Tolima': -75.2322235,
#  'Valle del Cauca': -76.52249909999999,
#  'Vaupés': -70.23472,
#  'Vichada': -67.48588000000001}

# %%
latitud.head()
# Out:
#         nombre   latitud   longitud
# 0     Amazonas  -4.21528 -69.940560
# 1    Antioquia   6.25184 -75.563591
# 2       Arauca   7.08471 -70.759079
# 3    Atlántico  10.96854 -74.781319
# 4  Bogotá D.C.   4.60971 -74.081749
